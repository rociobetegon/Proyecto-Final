# %% [markdown]
# # 1 face facial recognition

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import pandas as pd
import numpy as np
import cv2
import glob
import Stemmer
# Out:
# Using TensorFlow backend.

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 

img = cv2.imread("Descargas/CK+/extended-cohn-kanade-images/cohn-kanade-images/S005/001/S005_001_00000001.png")
plt.imshow(img)

# %%
# Detect faces
#faces = face_cascade.detectMultiScale(img, 1.1, 4)
faces = face_cascade.detectMultiScale(img, 1.25, 6)
print(len(faces))
# Out:
# 1

# %%
# Draw rectangle around the faces
print("Detected {} faces".format(len(faces)))
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 4)
    break
# Out:
# Detected 1 faces

# %%
# Display the output
crop = img[y:y+h,x:x+w]
plt.imshow(crop,cmap='gray')

# %%
#Faces points
f = open("Descargas/CK+/Landmarks/S005/001/S005_001_00000001_landmarks.txt", "r")
print(f.read())

#convertirlo en un numpy array porque está en fichero texto, los puntos matplotlib con stem y sacar la primera 
#secuencia de todas
# Out:
#    2.1779878e+02   2.1708728e+02
#    2.1689078e+02   2.5486311e+02
#    2.2367206e+02   2.9207462e+02
#    2.3823885e+02   3.2679248e+02
#    2.5494789e+02   3.6061587e+02
#    2.7953139e+02   3.8890414e+02
#    3.1045043e+02   4.1042450e+02
#    3.4537818e+02   4.2529204e+02
#    3.8236266e+02   4.2851270e+02
#    4.1806689e+02   4.2413911e+02
#    4.4999561e+02   4.0856366e+02
#    4.7742884e+02   3.8563278e+02
#    4.9983194e+02   3.5772590e+02
#    5.0949470e+02   3.2337268e+02
#    5.1613174e+02   2.8786876e+02
#    5.1815853e+02   2.5206194e+02
#    5.1869634e+02   2.1655158e+02
#    2.4762010e+02   1.8034162e+02
#    2.6870792e+02   1.6539026e+02
#    2.9356778e+02   1.5893545e+02
#    3.1916937e+02   1.6078699e+02
#    3.4348894e+02   1.6915112e+02
#    3.9725624e+02   1.6428431e+02
#    4.2026527e+02   1.5648688e+02
#    4.4357508e+02   1.5079923e+02
#    4.6719522e+02   1.5484270e+02
#    4.8887233e+02   1.6542594e+02
#    3.7277664e+02   1.9950671e+02
# ...

# %%
np.dtype('f')
# Out:
# dtype('float32')

# %%
np.array("f")
# Out:
# array('f', dtype='<U1')

# %%
landmarks = np.loadtxt("Descargas/CK+/Landmarks/S005/001/S005_001_00000001_landmarks.txt")
landmarks
# Out:
# array([[217.79878, 217.08728],
#        [216.89078, 254.86311],
#        [223.67206, 292.07462],
#        [238.23885, 326.79248],
#        [254.94789, 360.61587],
#        [279.53139, 388.90414],
#        [310.45043, 410.4245 ],
#        [345.37818, 425.29204],
#        [382.36266, 428.5127 ],
#        [418.06689, 424.13911],
#        [449.99561, 408.56366],
#        [477.42884, 385.63278],
#        [499.83194, 357.7259 ],
#        [509.4947 , 323.37268],
#        [516.13174, 287.86876],
#        [518.15853, 252.06194],
#        [518.69634, 216.55158],
#        [247.6201 , 180.34162],
#        [268.70792, 165.39026],
#        [293.56778, 158.93545],
#        [319.16937, 160.78699],
#        [343.48894, 169.15112],
#        [397.25624, 164.28431],
#        [420.26527, 156.48688],
#        [443.57508, 150.79923],
#        [467.19522, 154.8427 ],
#        [488.87233, 165.42594],
#        [372.77664, 199.50671],
#        [373.99586, 223.36618],
#        [375.57578, 246.90136],
# ...

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)

# %%
# %matplotlib inline
plt.figure(figsize=(15, 5))
plt.imshow(img)
plt.scatter(landmarks[:, 0], landmarks[:, 1], alpha=0.8)
